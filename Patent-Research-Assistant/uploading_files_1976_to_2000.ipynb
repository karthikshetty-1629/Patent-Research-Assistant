# %%
import requests
import boto3
from bs4 import BeautifulSoup
import re

# %%
# Initializing the Boto3 S3 client
s3_client = boto3.client('s3')

# Base URL for the fulltext directory (1976-2000)
base_url_1976_2000 = 'https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/'

# S3 bucket name and folder
bucket_name = 'patent-research-assistant'  # Replace with your actual bucket name
s3_folder = 'uspto/fulltext'  # Target folder structure within the S3 bucket

# Defining the years for which the files need to be downloaded (1976 to 2000)
years_to_download = range(1976, 2001)

# %%
# Looping over each year to access its specific directory
for year in years_to_download:
    # Constructing the URL for the year directory
    year_url = f"{base_url_1976_2000}{year}/"
    zip_file_pattern = r'pftaps\d{8}_wk\d{2}\.zip$'  
    pdf_file_pattern = r'.*\.pdf$'  

    print(f"Accessing {year_url}...")

    try:
        # Sending a GET request to retrieve the page content
        response = requests.get(year_url)
        response.raise_for_status()

        # Parsing the page content
        soup = BeautifulSoup(response.text, 'html.parser')

        # Finding all .zip and .pdf links matching the specified patterns
        for link in soup.find_all('a', href=True):
            file_name = link['href']
            if re.match(zip_file_pattern, file_name) or re.match(pdf_file_pattern, file_name):
                file_url = year_url + file_name
                
                # Setting the S3 key with the target folder structure
                s3_key = f"{s3_folder}/{year}/{file_name}"

                print(f"Downloading {file_name} from {file_url}...")

                # Downloading the file
                file_response = requests.get(file_url, stream=True)
                file_response.raise_for_status()

                # Uploading directly to S3
                print(f"Uploading {file_name} to S3 bucket {bucket_name} at {s3_key}...")
                s3_client.upload_fileobj(file_response.raw, bucket_name, s3_key)

                print(f"Uploaded {file_name} successfully to {s3_key}.")

    except requests.exceptions.RequestException as e:
        print(f"Failed to access {year_url}: {e}")

print("All specified files downloaded and uploaded to S3.")
# Out:
# Accessing https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/...
# Downloading PatentFullTextAPSDoc_GreenBook.pdf from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/PatentFullTextAPSDoc_GreenBook.pdf...
# Uploading PatentFullTextAPSDoc_GreenBook.pdf to S3 bucket patent-research-assistant at uspto/fulltext/2000/PatentFullTextAPSDoc_GreenBook.pdf...
# Uploaded PatentFullTextAPSDoc_GreenBook.pdf successfully to uspto/fulltext/2000/PatentFullTextAPSDoc_GreenBook.pdf.
# Downloading pftaps20000104_wk01.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000104_wk01.zip...
# Uploading pftaps20000104_wk01.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000104_wk01.zip...
# Uploaded pftaps20000104_wk01.zip successfully to uspto/fulltext/2000/pftaps20000104_wk01.zip.
# Downloading pftaps20000111_wk02.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000111_wk02.zip...
# Uploading pftaps20000111_wk02.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000111_wk02.zip...
# Uploaded pftaps20000111_wk02.zip successfully to uspto/fulltext/2000/pftaps20000111_wk02.zip.
# Downloading pftaps20000118_wk03.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000118_wk03.zip...
# Uploading pftaps20000118_wk03.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000118_wk03.zip...
# Uploaded pftaps20000118_wk03.zip successfully to uspto/fulltext/2000/pftaps20000118_wk03.zip.
# Downloading pftaps20000125_wk04.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000125_wk04.zip...
# Uploading pftaps20000125_wk04.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000125_wk04.zip...
# Uploaded pftaps20000125_wk04.zip successfully to uspto/fulltext/2000/pftaps20000125_wk04.zip.
# Downloading pftaps20000201_wk05.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000201_wk05.zip...
# Uploading pftaps20000201_wk05.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000201_wk05.zip...
# Uploaded pftaps20000201_wk05.zip successfully to uspto/fulltext/2000/pftaps20000201_wk05.zip.
# Downloading pftaps20000208_wk06.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000208_wk06.zip...
# Uploading pftaps20000208_wk06.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000208_wk06.zip...
# Uploaded pftaps20000208_wk06.zip successfully to uspto/fulltext/2000/pftaps20000208_wk06.zip.
# Downloading pftaps20000215_wk07.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000215_wk07.zip...
# Uploading pftaps20000215_wk07.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000215_wk07.zip...
# Uploaded pftaps20000215_wk07.zip successfully to uspto/fulltext/2000/pftaps20000215_wk07.zip.
# Downloading pftaps20000222_wk08.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000222_wk08.zip...
# Uploading pftaps20000222_wk08.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000222_wk08.zip...
# Uploaded pftaps20000222_wk08.zip successfully to uspto/fulltext/2000/pftaps20000222_wk08.zip.
# Downloading pftaps20000229_wk09.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000229_wk09.zip...
# Uploading pftaps20000229_wk09.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000229_wk09.zip...
# Uploaded pftaps20000229_wk09.zip successfully to uspto/fulltext/2000/pftaps20000229_wk09.zip.
# Downloading pftaps20000307_wk10.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000307_wk10.zip...
# Uploading pftaps20000307_wk10.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000307_wk10.zip...
# Uploaded pftaps20000307_wk10.zip successfully to uspto/fulltext/2000/pftaps20000307_wk10.zip.
# Downloading pftaps20000314_wk11.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000314_wk11.zip...
# Uploading pftaps20000314_wk11.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000314_wk11.zip...
# Uploaded pftaps20000314_wk11.zip successfully to uspto/fulltext/2000/pftaps20000314_wk11.zip.
# Downloading pftaps20000321_wk12.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000321_wk12.zip...
# Uploading pftaps20000321_wk12.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000321_wk12.zip...
# Uploaded pftaps20000321_wk12.zip successfully to uspto/fulltext/2000/pftaps20000321_wk12.zip.
# Downloading pftaps20000328_wk13.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000328_wk13.zip...
# Uploading pftaps20000328_wk13.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000328_wk13.zip...
# Uploaded pftaps20000328_wk13.zip successfully to uspto/fulltext/2000/pftaps20000328_wk13.zip.
# Downloading pftaps20000404_wk14.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000404_wk14.zip...
# Uploading pftaps20000404_wk14.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000404_wk14.zip...
# Uploaded pftaps20000404_wk14.zip successfully to uspto/fulltext/2000/pftaps20000404_wk14.zip.
# Downloading pftaps20000411_wk15.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000411_wk15.zip...
# Uploading pftaps20000411_wk15.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000411_wk15.zip...
# Uploaded pftaps20000411_wk15.zip successfully to uspto/fulltext/2000/pftaps20000411_wk15.zip.
# Downloading pftaps20000418_wk16.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000418_wk16.zip...
# Uploading pftaps20000418_wk16.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000418_wk16.zip...
# Uploaded pftaps20000418_wk16.zip successfully to uspto/fulltext/2000/pftaps20000418_wk16.zip.
# Downloading pftaps20000425_wk17.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000425_wk17.zip...
# Uploading pftaps20000425_wk17.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000425_wk17.zip...
# Uploaded pftaps20000425_wk17.zip successfully to uspto/fulltext/2000/pftaps20000425_wk17.zip.
# Downloading pftaps20000502_wk18.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000502_wk18.zip...
# Uploading pftaps20000502_wk18.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000502_wk18.zip...
# Uploaded pftaps20000502_wk18.zip successfully to uspto/fulltext/2000/pftaps20000502_wk18.zip.
# Downloading pftaps20000509_wk19.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000509_wk19.zip...
# Uploading pftaps20000509_wk19.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000509_wk19.zip...
# Uploaded pftaps20000509_wk19.zip successfully to uspto/fulltext/2000/pftaps20000509_wk19.zip.
# Downloading pftaps20000516_wk20.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000516_wk20.zip...
# Uploading pftaps20000516_wk20.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000516_wk20.zip...
# Uploaded pftaps20000516_wk20.zip successfully to uspto/fulltext/2000/pftaps20000516_wk20.zip.
# Downloading pftaps20000523_wk21.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000523_wk21.zip...
# Uploading pftaps20000523_wk21.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000523_wk21.zip...
# Uploaded pftaps20000523_wk21.zip successfully to uspto/fulltext/2000/pftaps20000523_wk21.zip.
# Downloading pftaps20000530_wk22.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000530_wk22.zip...
# Uploading pftaps20000530_wk22.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000530_wk22.zip...
# Uploaded pftaps20000530_wk22.zip successfully to uspto/fulltext/2000/pftaps20000530_wk22.zip.
# Downloading pftaps20000606_wk23.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000606_wk23.zip...
# Uploading pftaps20000606_wk23.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000606_wk23.zip...
# Uploaded pftaps20000606_wk23.zip successfully to uspto/fulltext/2000/pftaps20000606_wk23.zip.
# Downloading pftaps20000613_wk24.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000613_wk24.zip...
# Uploading pftaps20000613_wk24.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000613_wk24.zip...
# Uploaded pftaps20000613_wk24.zip successfully to uspto/fulltext/2000/pftaps20000613_wk24.zip.
# Downloading pftaps20000620_wk25.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000620_wk25.zip...
# Uploading pftaps20000620_wk25.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000620_wk25.zip...
# Uploaded pftaps20000620_wk25.zip successfully to uspto/fulltext/2000/pftaps20000620_wk25.zip.
# Downloading pftaps20000627_wk26.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000627_wk26.zip...
# Uploading pftaps20000627_wk26.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000627_wk26.zip...
# Uploaded pftaps20000627_wk26.zip successfully to uspto/fulltext/2000/pftaps20000627_wk26.zip.
# Downloading pftaps20000704_wk27.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000704_wk27.zip...
# Uploading pftaps20000704_wk27.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000704_wk27.zip...
# Uploaded pftaps20000704_wk27.zip successfully to uspto/fulltext/2000/pftaps20000704_wk27.zip.
# Downloading pftaps20000711_wk28.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000711_wk28.zip...
# Uploading pftaps20000711_wk28.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000711_wk28.zip...
# Uploaded pftaps20000711_wk28.zip successfully to uspto/fulltext/2000/pftaps20000711_wk28.zip.
# Downloading pftaps20000718_wk29.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000718_wk29.zip...
# Uploading pftaps20000718_wk29.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000718_wk29.zip...
# Uploaded pftaps20000718_wk29.zip successfully to uspto/fulltext/2000/pftaps20000718_wk29.zip.
# Downloading pftaps20000725_wk30.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000725_wk30.zip...
# Uploading pftaps20000725_wk30.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000725_wk30.zip...
# Uploaded pftaps20000725_wk30.zip successfully to uspto/fulltext/2000/pftaps20000725_wk30.zip.
# Downloading pftaps20000801_wk31.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000801_wk31.zip...
# Uploading pftaps20000801_wk31.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000801_wk31.zip...
# Uploaded pftaps20000801_wk31.zip successfully to uspto/fulltext/2000/pftaps20000801_wk31.zip.
# Downloading pftaps20000808_wk32.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000808_wk32.zip...
# Uploading pftaps20000808_wk32.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000808_wk32.zip...
# Uploaded pftaps20000808_wk32.zip successfully to uspto/fulltext/2000/pftaps20000808_wk32.zip.
# Downloading pftaps20000815_wk33.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000815_wk33.zip...
# Uploading pftaps20000815_wk33.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000815_wk33.zip...
# Uploaded pftaps20000815_wk33.zip successfully to uspto/fulltext/2000/pftaps20000815_wk33.zip.
# Downloading pftaps20000822_wk34.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000822_wk34.zip...
# Uploading pftaps20000822_wk34.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000822_wk34.zip...
# Uploaded pftaps20000822_wk34.zip successfully to uspto/fulltext/2000/pftaps20000822_wk34.zip.
# Downloading pftaps20000829_wk35.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000829_wk35.zip...
# Uploading pftaps20000829_wk35.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000829_wk35.zip...
# Uploaded pftaps20000829_wk35.zip successfully to uspto/fulltext/2000/pftaps20000829_wk35.zip.
# Downloading pftaps20000905_wk36.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000905_wk36.zip...
# Uploading pftaps20000905_wk36.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000905_wk36.zip...
# Uploaded pftaps20000905_wk36.zip successfully to uspto/fulltext/2000/pftaps20000905_wk36.zip.
# Downloading pftaps20000912_wk37.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000912_wk37.zip...
# Uploading pftaps20000912_wk37.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000912_wk37.zip...
# Uploaded pftaps20000912_wk37.zip successfully to uspto/fulltext/2000/pftaps20000912_wk37.zip.
# Downloading pftaps20000919_wk38.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000919_wk38.zip...
# Uploading pftaps20000919_wk38.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000919_wk38.zip...
# Uploaded pftaps20000919_wk38.zip successfully to uspto/fulltext/2000/pftaps20000919_wk38.zip.
# Downloading pftaps20000926_wk39.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20000926_wk39.zip...
# Uploading pftaps20000926_wk39.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20000926_wk39.zip...
# Uploaded pftaps20000926_wk39.zip successfully to uspto/fulltext/2000/pftaps20000926_wk39.zip.
# Downloading pftaps20001003_wk40.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20001003_wk40.zip...
# Uploading pftaps20001003_wk40.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20001003_wk40.zip...
# Uploaded pftaps20001003_wk40.zip successfully to uspto/fulltext/2000/pftaps20001003_wk40.zip.
# Downloading pftaps20001010_wk41.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20001010_wk41.zip...
# Uploading pftaps20001010_wk41.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20001010_wk41.zip...
# Uploaded pftaps20001010_wk41.zip successfully to uspto/fulltext/2000/pftaps20001010_wk41.zip.
# Downloading pftaps20001017_wk42.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20001017_wk42.zip...
# Uploading pftaps20001017_wk42.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20001017_wk42.zip...
# Uploaded pftaps20001017_wk42.zip successfully to uspto/fulltext/2000/pftaps20001017_wk42.zip.
# Downloading pftaps20001024_wk43.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20001024_wk43.zip...
# Uploading pftaps20001024_wk43.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20001024_wk43.zip...
# Uploaded pftaps20001024_wk43.zip successfully to uspto/fulltext/2000/pftaps20001024_wk43.zip.
# Downloading pftaps20001031_wk44.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20001031_wk44.zip...
# Uploading pftaps20001031_wk44.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20001031_wk44.zip...
# Uploaded pftaps20001031_wk44.zip successfully to uspto/fulltext/2000/pftaps20001031_wk44.zip.
# Downloading pftaps20001107_wk45.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20001107_wk45.zip...
# Uploading pftaps20001107_wk45.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20001107_wk45.zip...
# Uploaded pftaps20001107_wk45.zip successfully to uspto/fulltext/2000/pftaps20001107_wk45.zip.
# Downloading pftaps20001114_wk46.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20001114_wk46.zip...
# Uploading pftaps20001114_wk46.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20001114_wk46.zip...
# Uploaded pftaps20001114_wk46.zip successfully to uspto/fulltext/2000/pftaps20001114_wk46.zip.
# Downloading pftaps20001121_wk47.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20001121_wk47.zip...
# Uploading pftaps20001121_wk47.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20001121_wk47.zip...
# Uploaded pftaps20001121_wk47.zip successfully to uspto/fulltext/2000/pftaps20001121_wk47.zip.
# Downloading pftaps20001128_wk48.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20001128_wk48.zip...
# Uploading pftaps20001128_wk48.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20001128_wk48.zip...
# Uploaded pftaps20001128_wk48.zip successfully to uspto/fulltext/2000/pftaps20001128_wk48.zip.
# Downloading pftaps20001205_wk49.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20001205_wk49.zip...
# Uploading pftaps20001205_wk49.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20001205_wk49.zip...
# Uploaded pftaps20001205_wk49.zip successfully to uspto/fulltext/2000/pftaps20001205_wk49.zip.
# Downloading pftaps20001212_wk50.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20001212_wk50.zip...
# Uploading pftaps20001212_wk50.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20001212_wk50.zip...
# Uploaded pftaps20001212_wk50.zip successfully to uspto/fulltext/2000/pftaps20001212_wk50.zip.
# Downloading pftaps20001219_wk51.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20001219_wk51.zip...
# Uploading pftaps20001219_wk51.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20001219_wk51.zip...
# Uploaded pftaps20001219_wk51.zip successfully to uspto/fulltext/2000/pftaps20001219_wk51.zip.
# Downloading pftaps20001226_wk52.zip from https://bulkdata.uspto.gov/data/patent/grant/redbook/fulltext/2000/pftaps20001226_wk52.zip...
# Uploading pftaps20001226_wk52.zip to S3 bucket patent-research-assistant at uspto/fulltext/2000/pftaps20001226_wk52.zip...
# Uploaded pftaps20001226_wk52.zip successfully to uspto/fulltext/2000/pftaps20001226_wk52.zip.
# All specified files downloaded and uploaded to S3.
